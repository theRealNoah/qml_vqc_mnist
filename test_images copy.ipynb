# %%
import qiskit

qc = qiskit.QuantumCircuit(2)
qc.h(0)
qc.x(1)
qc.draw('mpl')

# %%
import qiskit

qc = qiskit.QuantumCircuit(2)
qc.cx(0, 1)
qc.draw('mpl')

# %%
import qiskit

qc = qiskit.QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.draw('mpl')

# %%
import qiskit

qc = qiskit.QuantumCircuit(4)
qc.h(0)
qc.x(1)
qc.cx(0,1)
qc.y(2)
qc.z(3)
qc.draw('mpl')
